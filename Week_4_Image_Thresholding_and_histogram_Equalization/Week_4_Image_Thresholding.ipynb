# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
my_img = cv2.imread("./resim.jpg",1)
my_img_gray = cv2.cvtColor(my_img,cv2.COLOR_BGR2GRAY)

# %%
_,my_thresh_binary = cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_BINARY)

# %%
fig =plt.figure(figsize=(10,7))
rows =1
columns =2

fig.add_subplot(rows,columns,1)
plt.imshow(my_img_gray,cmap="gray")
plt.axis('off')
plt.title("ORIGINAL")


fig.add_subplot(rows,columns,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("Binary Thresholding ımage")
# Out:
# Text(0.5, 1.0, 'Binary Thresholding ımage')

# %%
_,my_thresh_binary_inv = cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_BINARY_INV)

# %%
fig =plt.figure(figsize=(10,7))
rows =1
columns =3

fig.add_subplot(rows,columns,1)
plt.imshow(my_img_gray,cmap="gray")
plt.axis('off')
plt.title("ORIGINAL")


fig.add_subplot(rows,columns,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("Binary Thresholding ımage")


fig.add_subplot(rows,columns,3)
plt.imshow(my_thresh_binary_inv,cmap="gray")
plt.axis('off')
plt.title("Binary inv Thresholding ımage")
# Out:
# Text(0.5, 1.0, 'Binary inv Thresholding ımage')

# %%
_,my_thresh_trunc= cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_TRUNC)_,my_thresh_trunc= cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_TRUNC)
# Out:
#   Cell In[15], line 2
#     type=cv2.THRESH_TRUNC)_,my_thresh_trunc= cv2.threshold(my_img_gray,thresh =128 , maxval=255,
#                           ^
# SyntaxError: invalid syntax

# %%
fig =plt.figure(figsize=(12,7))
rows =2
columns =2

fig.add_subplot(rows,columns,1)
plt.imshow(my_img_gray,cmap="gray")
plt.axis('off')
plt.title("ORIGINAL")


fig.add_subplot(rows,columns,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("Binary Thresholding ımage")


fig.add_subplot(rows,columns,3)
plt.imshow(my_thresh_binary_inv,cmap="gray")
plt.axis('off')
plt.title("Binary inv Thresholding ımage")

fig.add_subplot(rows,columns,4)
plt.imshow(my_thresh_trunc,cmap="gray")
plt.axis('off')
plt.title("TRUNC  Thresholding ımage")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 23
#      20 plt.title("Binary inv Thresholding ımage")
#      22 fig.add_subplot(rows,columns,4)
# ---> 23 plt.imshow(my_thresh_trunc,cmap="gray")
#      24 plt.axis('off')
#      25 plt.title("TRUNC  Thresholding ımage")
#
# NameError: name 'my_thresh_trunc' is not defined

# %%
_,my_thresh_tozero= cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_TOZERO)

# %%
_,my_thresh_tozero_inv= cv2.threshold(my_img_gray,thresh =128 , maxval=255,
                                           type=cv2.THRESH_TOZERO_INV)

# %%
fig =plt.figure(figsize=(12,7))
rows =2
columns =3

fig.add_subplot(rows,columns,1)
plt.imshow(my_img_gray,cmap="gray")
plt.axis('off')
plt.title("ORIGINAL")


fig.add_subplot(rows,columns,2)
plt.imshow(my_thresh_binary,cmap="gray")
plt.axis('off')
plt.title("Binary Thresholding ımage")


fig.add_subplot(rows,columns,3)
plt.imshow(my_thresh_binary_inv,cmap="gray")
plt.axis('off')
plt.title("Binary inv Thresholding ımage")

fig.add_subplot(rows,columns,4)
plt.imshow(my_thresh_trunc,cmap="gray")
plt.axis('off')
plt.title("TRUNC  Thresholding ımage")

fig.add_subplot(rows,columns,5)
plt.imshow(my_thresh_tozero,cmap="gray")
plt.axis('off')
plt.title("TOZERO Thresholding ımage")

fig.add_subplot(rows,columns,6)
plt.imshow(my_thresh_tozero_inv,cmap="gray")
plt.axis('off')
plt.title("TOZERO  Thresholding ımage")

plt.tight_layout()
plt.savefig("./my_all_thresh_images.png",dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 23
#      20 plt.title("Binary inv Thresholding ımage")
#      22 fig.add_subplot(rows,columns,4)
# ---> 23 plt.imshow(my_thresh_trunc,cmap="gray")
#      24 plt.axis('off')
#      25 plt.title("TRUNC  Thresholding ımage")
#
# NameError: name 'my_thresh_trunc' is not defined

# %%
plt.imshow(my_thresh_tozero_inv,cmap="gray")
plt.axis('off')


plt.tight_layout()
plt.savefig("./my_thresh_tozero.png",dpi=300)
plt.show()
